# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#To ignore warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\M SWETHA\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: openpyxl in c:\users\m swetha\appdata\roaming\python\python311\site-packages (3.1.0)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# Data Set

# %%
file1=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\bps_2011_report_english.xlsx')
file2=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\bps_2012_report_english.xlsx')
file3=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\bps_2013_report_english.xlsx')
file4=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\bps_2014_report_english.xlsx')
file5=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\bps_2015_report_english.xlsx')
file6=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\bps_2016_report_english.xlsx')
file7=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\2017_energy_consumption.xlsx')
file8=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\2018_final_data_set.xlsx')
file9=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\2019_final_data_set.xlsx')
file10=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\2020_final_data_set.xlsx')
file11=pd.read_excel('C:\\Users\\M SWETHA\\Downloads\\2021_final_bps_dataset (2).xlsx')

# %% [markdown]
# Merge the Data Set

# %%
file1.head(5)
# Out:
#   The GJ/m2 column has been updated to address conversion irregularities.  \
# 0                                                NaN
# 1                                        Sector Name
# 2                                          Municipal
# 3                                          Municipal
# 4                                          Municipal
#
#        Unnamed: 1         Unnamed: 2             Unnamed: 3  \
# 0             NaN                NaN                    NaN
# 1  SubSector Name  Organization Name         Operation Name
# 2    Municipality   Town of Goderich       Municipal Office
# 3    Municipality   Town of Goderich       Goderich Library
# 4    Municipality   Town of Goderich  Water Treatment Plant
#
#                                           Unnamed: 4          Unnamed: 5  \
# 0                                                NaN                 NaN
# 1                                     Operation Type             Address
# 2  Administrative offices and related facilities,...      57 West Street
# 3                                   Public libraries  52 Montreal Street
# 4       Facilities related to the treatment of water         100 Cove Rd
#
#   Unnamed: 6   Unnamed: 7        Unnamed: 8     Unnamed: 9  ... Unnamed: 31  \
# 0        NaN          NaN               NaN            NaN  ...         NaN
# 1       City  Postal Code  Total Floor Area          Unit1  ...      Unit10
# 2   Goderich      N7A 2K5             21510    Square feet  ...         NaN
# 3   Goderich      N7A 2K5              1100  Square meters  ...         NaN
# 4   Goderich      N7A 2K5               733  Square meters  ...         NaN
#
#   Unnamed: 32       Unnamed: 33    Unnamed: 34          Unnamed: 35  \
# 0         NaN               NaN            NaN                  NaN
# 1  Renewable2  Emission Factor2  Swimming Pool  Number of Portables
# 2       False               NaN          False                  NaN
# 3       False               NaN          False                  NaN
# 4       False               NaN          False                  NaN
#
#          Unnamed: 36                 Unnamed: 37  \
# 0                NaN                         NaN
# 1  GHG Emissions(Kg)  Energy Intensity ekWh_sqft
# 2        24740.49079                   11.650264
# 3       45163.116457                   25.237567
# 4        97528.52532                  126.078258
#
#                         Unnamed: 38             Unnamed: 39  \
# 0                               NaN                     NaN
# 1  Energy Intensity ekWh_mega_litre  Energy Intensity GJ_m2
# 2                               NaN                0.451449
# 3                               NaN                0.977989
# 4                        707.712764                4.885701
#
#                       Unnamed: 40
# 0                             NaN
# 1  Energy Intensity GJ_mega_litre
# 2                             NaN
# 3                             NaN
# 4                        2.547766
#
# [5 rows x 41 columns]

# %%
pd.set_option('display.max_columns',None)
file1.head(5)
# Out:
#   The GJ/m2 column has been updated to address conversion irregularities.  \
# 0                                                NaN
# 1                                        Sector Name
# 2                                          Municipal
# 3                                          Municipal
# 4                                          Municipal
#
#        Unnamed: 1         Unnamed: 2             Unnamed: 3  \
# 0             NaN                NaN                    NaN
# 1  SubSector Name  Organization Name         Operation Name
# 2    Municipality   Town of Goderich       Municipal Office
# 3    Municipality   Town of Goderich       Goderich Library
# 4    Municipality   Town of Goderich  Water Treatment Plant
#
#                                           Unnamed: 4          Unnamed: 5  \
# 0                                                NaN                 NaN
# 1                                     Operation Type             Address
# 2  Administrative offices and related facilities,...      57 West Street
# 3                                   Public libraries  52 Montreal Street
# 4       Facilities related to the treatment of water         100 Cove Rd
#
#   Unnamed: 6   Unnamed: 7        Unnamed: 8     Unnamed: 9  Unnamed: 10  \
# 0        NaN          NaN               NaN            NaN          NaN
# 1       City  Postal Code  Total Floor Area          Unit1  Annual Flow
# 2   Goderich      N7A 2K5             21510    Square feet          NaN
# 3   Goderich      N7A 2K5              1100  Square meters          NaN
# 4   Goderich      N7A 2K5               733  Square meters     1405.631
#
#               Unnamed: 11  Unnamed: 12 Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0                     NaN          NaN         NaN          NaN          NaN
# 1  Average Hours Per Week  Electricity       Unit2  Natural Gas        Unit3
# 2                      40       248444         kWh        202.6  Cubic meter
# 3                      62       100147         kWh      18694.7  Cubic meter
# 4                     168       994783         kWh          NaN          NaN
#
#       Unnamed: 16 Unnamed: 17     Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0             NaN         NaN             NaN         NaN         NaN
# 1  Fuel Oil 1 & 2       Unit4  Fuel Oil 4 & 6       Unit5     Propane
# 2             NaN         NaN             NaN         NaN         NaN
# 3             NaN         NaN             NaN         NaN         NaN
# 4             NaN         NaN             NaN         NaN         NaN
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25    Unnamed: 26  \
# 0         NaN         NaN         NaN         NaN         NaN            NaN
# 1       Unit6        Coal       Unit7        Wood       Unit8  District Heat
# 2         NaN         NaN         NaN         NaN         NaN            NaN
# 3         NaN         NaN         NaN         NaN         NaN            NaN
# 4         NaN         NaN         NaN         NaN         NaN            NaN
#
#   Unnamed: 27 Unnamed: 28       Unnamed: 29    Unnamed: 30 Unnamed: 31  \
# 0         NaN         NaN               NaN            NaN         NaN
# 1       Unit9  Renewable1  Emission Factor1  District Cool      Unit10
# 2         NaN       False               NaN            NaN         NaN
# 3         NaN       False               NaN            NaN         NaN
# 4         NaN       False               NaN            NaN         NaN
#
#   Unnamed: 32       Unnamed: 33    Unnamed: 34          Unnamed: 35  \
# 0         NaN               NaN            NaN                  NaN
# 1  Renewable2  Emission Factor2  Swimming Pool  Number of Portables
# 2       False               NaN          False                  NaN
# 3       False               NaN          False                  NaN
# 4       False               NaN          False                  NaN
#
#          Unnamed: 36                 Unnamed: 37  \
# 0                NaN                         NaN
# 1  GHG Emissions(Kg)  Energy Intensity ekWh_sqft
# 2        24740.49079                   11.650264
# 3       45163.116457                   25.237567
# 4        97528.52532                  126.078258
#
#                         Unnamed: 38             Unnamed: 39  \
# 0                               NaN                     NaN
# 1  Energy Intensity ekWh_mega_litre  Energy Intensity GJ_m2
# 2                               NaN                0.451449
# 3                               NaN                0.977989
# 4                        707.712764                4.885701
#
#                       Unnamed: 40
# 0                             NaN
# 1  Energy Intensity GJ_mega_litre
# 2                             NaN
# 3                             NaN
# 4                        2.547766

# %%
column_name_mapping = {
    'Sector Name': 'Sector',
    'SubSector Name': 'SubSector',
    'Organization Name' : 'Organization',
    'Operation Name':'Operation',
    'Average Hours Per Week':'Weekly Average Hours',
    'Total Floor Area':'Total Indoor Space_x',
    'Unit1':'Unit of Measure',
    'Annual Flow':'Annual Flow (M)',
    'Electricity':'Electricity_Quantity',
    'Unit2':'Electricity_Unit',
    'Natural Gas':'NaturalGas_Quantity',
    'Unit3':'NaturalGas_Unit',
    'Fuel Oil 1 & 2':'FuelOil12_Quantity',
    'Unit4':'FuelOil12_Unit',
    'Fuel Oil 4 & 6':'FuelOil46_Quantity',
    'Unit5':'FuelOil46_Unit',
    'Propane':'Propane_Quantity',
    'Unit6':'Propane_Unit',
    'Coal':'Coal_Quantity',
    'Unit7':'Coal_Unit',
    'Wood':'Wood_Quantity',
    'Unit8':'Wood_Unit',
    'District Heat':'DistrictHeating_Quantity',
    'Unit9':'DistrictHeating_Unit',
    'Renewable1':'DistrictHeating_IsRenewable',
    'Emission Factor1':'DistrictHeating_RenewableEmissionFactor',
    'District Cool':'DistrictCooling_Quantity',
    'Unit10':'DistrictCooling_Unit',
    'Renewable2':'DistrictCooling_IsRenewable',
    'Emission Factor2':'DistrictCooling_RenewableEmissionFactor',
    'GHG Emissions(Kg)':'GHG Emissions KG',
    
}

# %%
file1 = file1.rename(columns=column_name_mapping)

# %%
file1.columns
# Out:
# Index(['The GJ/m2 column has been updated to address conversion irregularities.',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40'],
#       dtype='object')

# %%
column_name_mapping = {
    'Sector Name': 'Sector',
    'Sub Sector ': 'SubSector',
    'Organization Name' : 'Organization',
    'Operation Name':'Operation',
    'Average Hours per week':'Weekly Average Hours',
    'Total Floor Area ':'Total Indoor Space_x',
    'Unit':'Unit of Measure',
    'Annual Flow ':'Annual Flow (M)',
    'Electricity':'Electricity_Quantity',
    'Electricity Unit':'Electricity_Unit',
    'Natural Gas':'NaturalGas_Quantity',
    'Natural Gas2':'NaturalGas_Unit',
    'Fuel Oil 1 & 2':'FuelOil12_Quantity',
    'Fuel Oil 1 & 2 Unit':'FuelOil12_Unit',
    'Fuel Oil 4 &6':'FuelOil46_Quantity',
    'Fuel Oil 4 &6 Unit':'FuelOil46_Unit',
    'Propane':'Propane_Quantity',
    'Propane Unit':'Propane_Unit',
    'Coal Quantity':'Coal_Quantity',
    'Coal Unit':'Coal_Unit',
    'Wood':'Wood_Quantity',
    'Wood3':'Wood_Unit',
    'District Heating':'DistrictHeating_Quantity',
    'District Heating Unit':'DistrictHeating_Unit',
    'Renewable':'DistrictHeating_IsRenewable',
    'Renewable Emission Factor':'DistrictHeating_RenewableEmissionFactor',
    'District Cooling':'DistrictCooling_Quantity',
    'District Cooling Unit':'DistrictCooling_Unit',
    'District Cooling Renewable':'DistrictCooling_IsRenewable',
    'District Cooling Renewable Emission Factor':'DistrictCooling_RenewableEmissionFactor',
    'GHG Emissions(Kg)':'GHG Emissions KG',
    'Swimming Pools':'Swimming Pool'
}

# %%
file2 = file2.rename(columns=column_name_mapping)

# %%
file2.columns
# Out:
# Index(['The GJ/m2 column has been updated to address conversion irregularities.',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40'],
#       dtype='object')

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file3 = file3.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file4 = file4.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file5 = file5.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file6 = file6.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file7 = file7.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file8 = file8.rename(columns=column_name_mapping)

# %%
column_name_mapping = {'Annual Flow (M':'Annual Flow (M)','Sub Sector':'SubSector'}
file9 = file9.rename(columns=column_name_mapping)

# %%
df = pd.concat([file1, file10,file9,file8,file7,file6,file5,file4,file3,file2], ignore_index=True)
pd.set_option('display.max_columns',None)
df
# Out:
#        The GJ/m2 column has been updated to address conversion irregularities.  \
# 0                                                     NaN
# 1                                             Sector Name
# 2                                               Municipal
# 3                                               Municipal
# 4                                               Municipal
# ...                                                   ...
# 173845             Post-secondary Educational Institution
# 173846             Post-secondary Educational Institution
# 173847             Post-secondary Educational Institution
# 173848             Post-secondary Educational Institution
# 173849             Post-secondary Educational Institution
#
#             Unnamed: 1         Unnamed: 2  \
# 0                  NaN                NaN
# 1       SubSector Name  Organization Name
# 2         Municipality   Town of Goderich
# 3         Municipality   Town of Goderich
# 4         Municipality   Town of Goderich
# ...                ...                ...
# 173845     University     York University
# 173846     University     York University
# 173847     University     York University
# 173848     University     York University
# 173849     University     York University
#
#                                             Unnamed: 3  \
# 0                                                  NaN
# 1                                       Operation Name
# 2                                     Municipal Office
# 3                                     Goderich Library
# 4                                Water Treatment Plant
# ...                                                ...
# 173845  William Small Centre - PS2 Face Building (398)
# 173846                           Winters College (368)
# 173847                                 York Hall (304)
# 173848                          York Lanes (383) (450)
# 173849                 York University Bookstore (203)
#
#                                                Unnamed: 4  \
# 0                                                     NaN
# 1                                          Operation Type
# 2       Administrative offices and related facilities,...
# 3                                        Public libraries
# 4            Facilities related to the treatment of water
# ...                                                   ...
# 173845      Administrative offices and related facilities
# 173846      Administrative offices and related facilities
# 173847      Administrative offices and related facilities
# 173848      Administrative offices and related facilities
# 173849      Administrative offices and related facilities
#
#                  Unnamed: 5 Unnamed: 6   Unnamed: 7        Unnamed: 8  \
# 0                       NaN        NaN          NaN               NaN
# 1                   Address       City  Postal Code  Total Floor Area
# 2            57 West Street   Goderich      N7A 2K5             21510
# 3        52 Montreal Street   Goderich      N7A 2K5              1100
# 4               100 Cove Rd   Goderich      N7A 2K5               733
# ...                     ...        ...          ...               ...
# 173845    4700 Keele Street    Toronto       M3J1P3           4812.49
# 173846    4700 Keele Street    Toronto       M3J1P3           6897.26
# 173847  2275 Bayview Avenue    Toronto       M4N3M6          19992.81
# 173848    4700 Keele Street    Toronto       M3J1P3          10533.75
# 173849    4700 Keele Street    Toronto       M3J1P3           2482.49
#
#            Unnamed: 9  Unnamed: 10             Unnamed: 11  Unnamed: 12  \
# 0                 NaN          NaN                     NaN          NaN
# 1               Unit1  Annual Flow  Average Hours Per Week  Electricity
# 2         Square feet          NaN                      40       248444
# 3       Square meters          NaN                      62       100147
# 4       Square meters     1405.631                     168       994783
# ...               ...          ...                     ...          ...
# 173845  Square meters           61                       0      1898435
# 173846  Square meters           85                       0      1585386
# 173847  Square meters          112                       0      1829015
# 173848  Square meters          133                       0        90990
# 173849  Square meters           50                       0       548509
#
#        Unnamed: 13  Unnamed: 14  Unnamed: 15     Unnamed: 16 Unnamed: 17  \
# 0              NaN          NaN          NaN             NaN         NaN
# 1            Unit2  Natural Gas        Unit3  Fuel Oil 1 & 2       Unit4
# 2              kWh        202.6  Cubic meter             NaN         NaN
# 3              kWh      18694.7  Cubic meter             NaN         NaN
# 4              kWh          NaN          NaN             NaN         NaN
# ...            ...          ...          ...             ...         ...
# 173845         kWh            0  Cubic Meter               0       Litre
# 173846         kWh            0  Cubic Meter               0       Litre
# 173847         kWh            0  Cubic Meter               0       Litre
# 173848         kWh       244044  Cubic Meter               0       Litre
# 173849         kWh            0  Cubic Meter               0       Litre
#
#            Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0                  NaN         NaN         NaN         NaN         NaN
# 1       Fuel Oil 4 & 6       Unit5     Propane       Unit6        Coal
# 2                  NaN         NaN         NaN         NaN         NaN
# 3                  NaN         NaN         NaN         NaN         NaN
# 4                  NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 173845               0       Litre           0       Litre           0
# 173846               0       Litre           0       Litre           0
# 173847               0       Litre           0       Litre           0
# 173848               0       Litre           0       Litre           0
# 173849               0       Litre           0       Litre           0
#
#          Unnamed: 23 Unnamed: 24   Unnamed: 25    Unnamed: 26 Unnamed: 27  \
# 0                NaN         NaN           NaN            NaN         NaN
# 1              Unit7        Wood         Unit8  District Heat       Unit9
# 2                NaN         NaN           NaN            NaN         NaN
# 3                NaN         NaN           NaN            NaN         NaN
# 4                NaN         NaN           NaN            NaN         NaN
# ...              ...         ...           ...            ...         ...
# 173845  Metric Tonne           0  Metric Tonne       4580.683  Giga Joule
# 173846  Metric Tonne           0  Metric Tonne       17026.69  Giga Joule
# 173847  Metric Tonne           0  Metric Tonne       14146.56  Giga Joule
# 173848  Metric Tonne           0  Metric Tonne              0  Giga Joule
# 173849  Metric Tonne           0  Metric Tonne              0  Giga Joule
#
#        Unnamed: 28       Unnamed: 29    Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 0              NaN               NaN            NaN         NaN         NaN
# 1       Renewable1  Emission Factor1  District Cool      Unit10  Renewable2
# 2            False               NaN            NaN         NaN       False
# 3            False               NaN            NaN         NaN       False
# 4            False               NaN            NaN         NaN       False
# ...            ...               ...            ...         ...         ...
# 173845       False                 0       1910.829  Giga Joule       False
# 173846       False                 0       2374.588  Giga Joule       False
# 173847       False                 0              0  Giga Joule       False
# 173848       False                 0       4050.645  Giga Joule       False
# 173849       False                 0       1377.224  Giga Joule       False
#
#              Unnamed: 33    Unnamed: 34          Unnamed: 35  \
# 0                    NaN            NaN                  NaN
# 1       Emission Factor2  Swimming Pool  Number of Portables
# 2                    NaN          False                  NaN
# 3                    NaN          False                  NaN
# 4                    NaN          False                  NaN
# ...                  ...            ...                  ...
# 173845                 0              0                False
# 173846                 0              0                False
# 173847                 0              0                False
# 173848                 0              0                False
# 173849                 0              0                False
#
#               Unnamed: 36                 Unnamed: 37  \
# 0                     NaN                         NaN
# 1       GHG Emissions(Kg)  Energy Intensity ekWh_sqft
# 2             24740.49079                   11.650264
# 3            45163.116457                   25.237567
# 4             97528.52532                  126.078258
# ...                   ...                         ...
# 173845      469399.795928                   64.316827
# 173846     1181110.522967                   87.752824
# 173847     1014525.321786                   26.759251
# 173848      502880.945826                   26.684434
# 173849       63812.513172                   24.865427
#
#                              Unnamed: 38             Unnamed: 39  \
# 0                                    NaN                     NaN
# 1       Energy Intensity ekWh_mega_litre  Energy Intensity GJ_m2
# 2                                    NaN                0.451449
# 3                                    NaN                0.977989
# 4                             707.712764                4.885701
# ...                                  ...                     ...
# 173845                                 0                2.492283
# 173846                                 0                 3.40043
# 173847                                 0                1.036923
# 173848                                 0                1.034024
# 173849                                 0                0.963538
#
#                            Unnamed: 40 Sector SubSector Organization  \
# 0                                  NaN    NaN       NaN          NaN
# 1       Energy Intensity GJ_mega_litre    NaN       NaN          NaN
# 2                                  NaN    NaN       NaN          NaN
# 3                                  NaN    NaN       NaN          NaN
# 4                             2.547766    NaN       NaN          NaN
# ...                                ...    ...       ...          ...
# 173845                               0    NaN       NaN          NaN
# 173846                               0    NaN       NaN          NaN
# 173847                               0    NaN       NaN          NaN
# 173848                               0    NaN       NaN          NaN
# 173849                               0    NaN       NaN          NaN
#
#        Operation Operation Type Address City Postal Code  \
# 0            NaN            NaN     NaN  NaN         NaN
# 1            NaN            NaN     NaN  NaN         NaN
# 2            NaN            NaN     NaN  NaN         NaN
# 3            NaN            NaN     NaN  NaN         NaN
# 4            NaN            NaN     NaN  NaN         NaN
# ...          ...            ...     ...  ...         ...
# 173845       NaN            NaN     NaN  NaN         NaN
# 173846       NaN            NaN     NaN  NaN         NaN
# 173847       NaN            NaN     NaN  NaN         NaN
# 173848       NaN            NaN     NaN  NaN         NaN
# 173849       NaN            NaN     NaN  NaN         NaN
#
#         Total Indoor Space_x Unit of Measure  Weekly Average Hours  \
# 0                        NaN             NaN                   NaN
# 1                        NaN             NaN                   NaN
# 2                        NaN             NaN                   NaN
# 3                        NaN             NaN                   NaN
# 4                        NaN             NaN                   NaN
# ...                      ...             ...                   ...
# 173845                   NaN             NaN                   NaN
# 173846                   NaN             NaN                   NaN
# 173847                   NaN             NaN                   NaN
# 173848                   NaN             NaN                   NaN
# 173849                   NaN             NaN                   NaN
#
#         Annual Flow (M)  Number of Portables Swimming Pool  \
# 0                   NaN                  NaN           NaN
# 1                   NaN                  NaN           NaN
# 2                   NaN                  NaN           NaN
# 3                   NaN                  NaN           NaN
# 4                   NaN                  NaN           NaN
# ...                 ...                  ...           ...
# 173845              NaN                  NaN           NaN
# 173846              NaN                  NaN           NaN
# 173847              NaN                  NaN           NaN
# 173848              NaN                  NaN           NaN
# 173849              NaN                  NaN           NaN
#
#         Electricity_Quantity Electricity_Unit  NaturalGas_Quantity  \
# 0                        NaN              NaN                  NaN
# 1                        NaN              NaN                  NaN
# 2                        NaN              NaN                  NaN
# 3                        NaN              NaN                  NaN
# 4                        NaN              NaN                  NaN
# ...                      ...              ...                  ...
# 173845                   NaN              NaN                  NaN
# 173846                   NaN              NaN                  NaN
# 173847                   NaN              NaN                  NaN
# 173848                   NaN              NaN                  NaN
# 173849                   NaN              NaN                  NaN
#
#        NaturalGas_Unit  FuelOil12_Quantity FuelOil12_Unit  FuelOil46_Quantity  \
# 0                  NaN                 NaN            NaN                 NaN
# 1                  NaN                 NaN            NaN                 NaN
# 2                  NaN                 NaN            NaN                 NaN
# 3                  NaN                 NaN            NaN                 NaN
# 4                  NaN                 NaN            NaN                 NaN
# ...                ...                 ...            ...                 ...
# 173845             NaN                 NaN            NaN                 NaN
# 173846             NaN                 NaN            NaN                 NaN
# 173847             NaN                 NaN            NaN                 NaN
# 173848             NaN                 NaN            NaN                 NaN
# 173849             NaN                 NaN            NaN                 NaN
#
#        FuelOil46_Unit  Propane_Quantity Propane_Unit Coal_Quantity Coal_Unit  \
# 0                 NaN               NaN          NaN           NaN       NaN
# 1                 NaN               NaN          NaN           NaN       NaN
# 2                 NaN               NaN          NaN           NaN       NaN
# 3                 NaN               NaN          NaN           NaN       NaN
# 4                 NaN               NaN          NaN           NaN       NaN
# ...               ...               ...          ...           ...       ...
# 173845            NaN               NaN          NaN           NaN       NaN
# 173846            NaN               NaN          NaN           NaN       NaN
# 173847            NaN               NaN          NaN           NaN       NaN
# 173848            NaN               NaN          NaN           NaN       NaN
# 173849            NaN               NaN          NaN           NaN       NaN
#
#         Wood_Quantity Wood_Unit  DistrictHeating_Quantity  \
# 0                 NaN       NaN                       NaN
# 1                 NaN       NaN                       NaN
# 2                 NaN       NaN                       NaN
# 3                 NaN       NaN                       NaN
# 4                 NaN       NaN                       NaN
# ...               ...       ...                       ...
# 173845            NaN       NaN                       NaN
# 173846            NaN       NaN                       NaN
# 173847            NaN       NaN                       NaN
# 173848            NaN       NaN                       NaN
# 173849            NaN       NaN                       NaN
#
#        DistrictHeating_Unit DistrictHeating_IsRenewable  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ...                     ...                         ...
# 173845                  NaN                         NaN
# 173846                  NaN                         NaN
# 173847                  NaN                         NaN
# 173848                  NaN                         NaN
# 173849                  NaN                         NaN
#
#         DistrictHeating_RenewableEmissionFactor  DistrictCooling_Quantity  \
# 0                                           NaN                       NaN
# 1                                           NaN                       NaN
# 2                                           NaN                       NaN
# 3                                           NaN                       NaN
# 4                                           NaN                       NaN
# ...                                         ...                       ...
# 173845                                      NaN                       NaN
# 173846                                      NaN                       NaN
# 173847                                      NaN                       NaN
# 173848                                      NaN                       NaN
# 173849                                      NaN                       NaN
#
#        DistrictCooling_Unit DistrictCooling_IsRenewable  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ...                     ...                         ...
# 173845                  NaN                         NaN
# 173846                  NaN                         NaN
# 173847                  NaN                         NaN
# 173848                  NaN                         NaN
# 173849                  NaN                         NaN
#
#         DistrictCooling_RenewableEmissionFactor  GHG Emissions KG  \
# 0                                           NaN               NaN
# 1                                           NaN               NaN
# 2                                           NaN               NaN
# 3                                           NaN               NaN
# 4                                           NaN               NaN
# ...                                         ...               ...
# 173845                                      NaN               NaN
# 173846                                      NaN               NaN
# 173847                                      NaN               NaN
# 173848                                      NaN               NaN
# 173849                                      NaN               NaN
#
#         Energy Intensity ekWh_sqft  Energy Intensity ekWh_mega_litre  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
# ...                            ...                               ...
# 173845                         NaN                               NaN
# 173846                         NaN                               NaN
# 173847                         NaN                               NaN
# 173848                         NaN                               NaN
# 173849                         NaN                               NaN
#
#         Energy Intensity GJ_m2  Energy Intensity GJ_mega_litre
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
# ...                        ...                             ...
# 173845                     NaN                             NaN
# 173846                     NaN                             NaN
# 173847                     NaN                             NaN
# 173848                     NaN                             NaN
# 173849                     NaN                             NaN
#
# [173850 rows x 82 columns]

# %% [markdown]
# DATA Cleaning
# Handiling Missing Value

# %%
df.isnull().sum()
# Out:
# The GJ/m2 column has been updated to address conversion irregularities.    85227
# Unnamed: 1                                                                 85232
# Unnamed: 2                                                                 85227
# Unnamed: 3                                                                 85227
# Unnamed: 4                                                                 85227
#                                                                            ...
# GHG Emissions KG                                                           88661
# Energy Intensity ekWh_sqft                                                 88630
# Energy Intensity ekWh_mega_litre                                           88642
# Energy Intensity GJ_m2                                                     89230
# Energy Intensity GJ_mega_litre                                             89230
# Length: 82, dtype: int64

# %%
numeric_columns = df.select_dtypes(include=['float64']).columns
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].mean())

int_columns = df.select_dtypes(include=['int64']).columns
df[int_columns] = df[int_columns].fillna(df[int_columns].mean())

# categorical columns (using mode)
categorical_columns = df.select_dtypes(include=['object']).columns
df[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# The GJ/m2 column has been updated to address conversion irregularities.    0
# Unnamed: 1                                                                 0
# Unnamed: 2                                                                 0
# Unnamed: 3                                                                 0
# Unnamed: 4                                                                 0
#                                                                           ..
# GHG Emissions KG                                                           0
# Energy Intensity ekWh_sqft                                                 0
# Energy Intensity ekWh_mega_litre                                           0
# Energy Intensity GJ_m2                                                     0
# Energy Intensity GJ_mega_litre                                             0
# Length: 82, dtype: int64

# %%
Wrong Formate

# %%
df.dtypes
# Out:
# The GJ/m2 column has been updated to address conversion irregularities.     object
# Unnamed: 1                                                                  object
# Unnamed: 2                                                                  object
# Unnamed: 3                                                                  object
# Unnamed: 4                                                                  object
#                                                                             ...
# GHG Emissions KG                                                           float64
# Energy Intensity ekWh_sqft                                                 float64
# Energy Intensity ekWh_mega_litre                                           float64
# Energy Intensity GJ_m2                                                     float64
# Energy Intensity GJ_mega_litre                                             float64
# Length: 82, dtype: object

# %%
df.head(5)
# Out:
#   The GJ/m2 column has been updated to address conversion irregularities.  \
# 0                                          Municipal
# 1                                        Sector Name
# 2                                          Municipal
# 3                                          Municipal
# 4                                          Municipal
#
#        Unnamed: 1         Unnamed: 2             Unnamed: 3  \
# 0    Municipality    City of Toronto       Municipal Office
# 1  SubSector Name  Organization Name         Operation Name
# 2    Municipality   Town of Goderich       Municipal Office
# 3    Municipality   Town of Goderich       Goderich Library
# 4    Municipality   Town of Goderich  Water Treatment Plant
#
#                                           Unnamed: 4             Unnamed: 5  \
# 0                                             School  Intentionally Omitted
# 1                                     Operation Type                Address
# 2  Administrative offices and related facilities,...         57 West Street
# 3                                   Public libraries     52 Montreal Street
# 4       Facilities related to the treatment of water            100 Cove Rd
#
#   Unnamed: 6   Unnamed: 7        Unnamed: 8     Unnamed: 9  Unnamed: 10  \
# 0    Toronto      M3J 1P3                 0    Square feet          168
# 1       City  Postal Code  Total Floor Area          Unit1  Annual Flow
# 2   Goderich      N7A 2K5             21510    Square feet          168
# 3   Goderich      N7A 2K5              1100  Square meters          168
# 4   Goderich      N7A 2K5               733  Square meters     1405.631
#
#               Unnamed: 11  Unnamed: 12 Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0                       0            0         kWh            0          kWh
# 1  Average Hours Per Week  Electricity       Unit2  Natural Gas        Unit3
# 2                      40       248444         kWh        202.6  Cubic meter
# 3                      62       100147         kWh      18694.7  Cubic meter
# 4                     168       994783         kWh            0          kWh
#
#       Unnamed: 16  Unnamed: 17     Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0               0  Cubic Meter               0       Litre           0
# 1  Fuel Oil 1 & 2        Unit4  Fuel Oil 4 & 6       Unit5     Propane
# 2               0  Cubic Meter               0       Litre           0
# 3               0  Cubic Meter               0       Litre           0
# 4               0  Cubic Meter               0       Litre           0
#
#   Unnamed: 21 Unnamed: 22   Unnamed: 23 Unnamed: 24   Unnamed: 25  \
# 0       Litre           0  Metric Tonne           0  Metric Tonne
# 1       Unit6        Coal         Unit7        Wood         Unit8
# 2       Litre           0  Metric Tonne           0  Metric Tonne
# 3       Litre           0  Metric Tonne           0  Metric Tonne
# 4       Litre           0  Metric Tonne           0  Metric Tonne
#
#      Unnamed: 26 Unnamed: 27 Unnamed: 28       Unnamed: 29    Unnamed: 30  \
# 0              0  Giga Joule       False                 0              0
# 1  District Heat       Unit9  Renewable1  Emission Factor1  District Cool
# 2              0  Giga Joule       False                 0              0
# 3              0  Giga Joule       False                 0              0
# 4              0  Giga Joule       False                 0              0
#
#   Unnamed: 31 Unnamed: 32       Unnamed: 33    Unnamed: 34  \
# 0           0       False                 0          False
# 1      Unit10  Renewable2  Emission Factor2  Swimming Pool
# 2           0       False                 0          False
# 3           0       False                 0          False
# 4           0       False                 0          False
#
#            Unnamed: 35        Unnamed: 36                 Unnamed: 37  \
# 0                    0                  0                           0
# 1  Number of Portables  GHG Emissions(Kg)  Energy Intensity ekWh_sqft
# 2                    0        24740.49079                   11.650264
# 3                    0       45163.116457                   25.237567
# 4                    0        97528.52532                  126.078258
#
#                         Unnamed: 38             Unnamed: 39  \
# 0                                 0                       0
# 1  Energy Intensity ekWh_mega_litre  Energy Intensity GJ_m2
# 2                                 0                0.451449
# 3                                 0                0.977989
# 4                        707.712764                4.885701
#
#                       Unnamed: 40     Sector     SubSector     Organization  \
# 0                               0  Municipal  Municipality  City of Toronto
# 1  Energy Intensity GJ_mega_litre  Municipal  Municipality  City of Toronto
# 2                               0  Municipal  Municipality  City of Toronto
# 3                               0  Municipal  Municipality  City of Toronto
# 4                        2.547766  Municipal  Municipality  City of Toronto
#
#           Operation Operation Type                        Address     City  \
# 0  Municipal Office         School  public works related facility  Toronto
# 1  Municipal Office         School  public works related facility  Toronto
# 2  Municipal Office         School  public works related facility  Toronto
# 3  Municipal Office         School  public works related facility  Toronto
# 4  Municipal Office         School  public works related facility  Toronto
#
#   Postal Code  Total Indoor Space_x Unit of Measure  Weekly Average Hours  \
# 0     L6P 1K7          62193.294512     Square feet             86.723544
# 1     L6P 1K7          62193.294512     Square feet             86.723544
# 2     L6P 1K7          62193.294512     Square feet             86.723544
# 3     L6P 1K7          62193.294512     Square feet             86.723544
# 4     L6P 1K7          62193.294512     Square feet             86.723544
#
#    Annual Flow (M)  Number of Portables Swimming Pool  Electricity_Quantity  \
# 0     26559.940671             0.454669            No         583286.618229
# 1     26559.940671             0.454669            No         583286.618229
# 2     26559.940671             0.454669            No         583286.618229
# 3     26559.940671             0.454669            No         583286.618229
# 4     26559.940671             0.454669            No         583286.618229
#
#   Electricity_Unit  NaturalGas_Quantity NaturalGas_Unit  FuelOil12_Quantity  \
# 0              kWh         65775.708054     Cubic Meter          459.887452
# 1              kWh         65775.708054     Cubic Meter          459.887452
# 2              kWh         65775.708054     Cubic Meter          459.887452
# 3              kWh         65775.708054     Cubic Meter          459.887452
# 4              kWh         65775.708054     Cubic Meter          459.887452
#
#   FuelOil12_Unit  FuelOil46_Quantity FuelOil46_Unit  Propane_Quantity  \
# 0          Litre           37.766504          Litre        875.884213
# 1          Litre           37.766504          Litre        875.884213
# 2          Litre           37.766504          Litre        875.884213
# 3          Litre           37.766504          Litre        875.884213
# 4          Litre           37.766504          Litre        875.884213
#
#   Propane_Unit Coal_Quantity     Coal_Unit  Wood_Quantity     Wood_Unit  \
# 0        Litre             0  Metric Tonne       0.012873  Metric Tonne
# 1        Litre             0  Metric Tonne       0.012873  Metric Tonne
# 2        Litre             0  Metric Tonne       0.012873  Metric Tonne
# 3        Litre             0  Metric Tonne       0.012873  Metric Tonne
# 4        Litre             0  Metric Tonne       0.012873  Metric Tonne
#
#    DistrictHeating_Quantity DistrictHeating_Unit DistrictHeating_IsRenewable  \
# 0               2123.751138           Giga Joule                          No
# 1               2123.751138           Giga Joule                          No
# 2               2123.751138           Giga Joule                          No
# 3               2123.751138           Giga Joule                          No
# 4               2123.751138           Giga Joule                          No
#
#    DistrictHeating_RenewableEmissionFactor  DistrictCooling_Quantity  \
# 0                                 0.035018                 38.749584
# 1                                 0.035018                 38.749584
# 2                                 0.035018                 38.749584
# 3                                 0.035018                 38.749584
# 4                                 0.035018                 38.749584
#
#   DistrictCooling_Unit DistrictCooling_IsRenewable  \
# 0           Giga Joule                          No
# 1           Giga Joule                          No
# 2           Giga Joule                          No
# 3           Giga Joule                          No
# 4           Giga Joule                          No
#
#    DistrictCooling_RenewableEmissionFactor  GHG Emissions KG  \
# 0                                 0.001417     270524.755372
# 1                                 0.001417     270524.755372
# 2                                 0.001417     270524.755372
# 3                                 0.001417     270524.755372
# 4                                 0.001417     270524.755372
#
#    Energy Intensity ekWh_sqft  Energy Intensity ekWh_mega_litre  \
# 0                23480.507098                      3.511400e+12
# 1                23480.507098                      3.511400e+12
# 2                23480.507098                      3.511400e+12
# 3                23480.507098                      3.511400e+12
# 4                23480.507098                      3.511400e+12
#
#    Energy Intensity GJ_m2  Energy Intensity GJ_mega_litre
# 0              915.817854                    1.272888e+10
# 1              915.817854                    1.272888e+10
# 2              915.817854                    1.272888e+10
# 3              915.817854                    1.272888e+10
# 4              915.817854                    1.272888e+10

# %%
df['Coal_Quantity'].value_counts()
# Out:
# Coal_Quantity
# 0        173845
# Litre         4
# 1.0           1
# Name: count, dtype: int64

# %%
df['Swimming Pool'].describe()
# Out:
# count     173850
# unique         2
# top           No
# freq      173405
# Name: Swimming Pool, dtype: object

# %%
df['Coal_Quantity'] = pd.to_numeric(df['Coal_Quantity'], errors='coerce')

# %%
df['Coal_Quantity'].dtypes
# Out:
# dtype('float64')

# %%
df['DistrictHeating_IsRenewable'].value_counts()
# Out:
# DistrictHeating_IsRenewable
# No     173809
# 0          30
# Yes        11
# Name: count, dtype: int64

# %%
df['DistrictCooling_IsRenewable'].value_counts()
# Out:
# DistrictCooling_IsRenewable
# No     173811
# Yes        39
# Name: count, dtype: int64

# %%
df['DistrictHeating_IsRenewable'] = pd.to_numeric(df['DistrictHeating_IsRenewable'], errors='coerce')
df['DistrictCooling_IsRenewable'] = pd.to_numeric(df['DistrictCooling_IsRenewable'], errors='coerce')

# %%
df['DistrictHeating_IsRenewable'].dtypes
df['DistrictCooling_IsRenewable'].dtypes
# Out:
# dtype('float64')

# %%
object_data_cols = [var for var in df.columns if df[var].dtype == 'object']
object_data_cols
# Out:
# ['The GJ/m2 column has been updated to address conversion irregularities.',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Sector',
#  'SubSector',
#  'Organization',
#  'Operation',
#  'Operation Type',
#  'Address',
#  'City',
#  'Postal Code',
#  'Unit of Measure',
#  'Swimming Pool',
#  'Electricity_Unit',
#  'NaturalGas_Unit',
#  'FuelOil12_Unit',
#  'FuelOil46_Unit',
#  'Propane_Unit',
#  'Coal_Unit',
#  'Wood_Unit',
#  'DistrictHeating_Unit',
#  'DistrictCooling_Unit']

# %%
df['Sector'].value_counts()
# Out:
# Sector
# Municipal                                 143582
# School Board                               24611
# Post-Secondary Educational Institution      3759
# Public Hospital                             1898
# Name: count, dtype: int64

# %%
df['Sector'] = df['Sector'].replace({
                                    'Post-secondary Educational Institution':'Post-Secondary Educational Institution',
                                    'Public Hospital':'Hospital',
                                    
                                            })

# %%
df['SubSector'].value_counts()
# Out:
# SubSector
# Municipality               143215
# School Board                24611
# College                      2599
# Acute/Chronic Hospital       1500
# University                   1160
# Municipal Service Board       333
# Acute Hospital                251
# Chronic Hospital              147
# Township                       30
# Municipal                       4
# Name: count, dtype: int64

# %%
df['SubSector'] = df['SubSector'].replace({'Acute Hospital':'Acute/Chronic Hospital',
                                           'Chronic Hospital':'Acute/Chronic Hospital',
                                           'Acute/Chronic':'Acute/Chronic Hospital',
                                           'Acute':'Acute/Chronic Hospital',
                                           'Chronic':'Acute/Chronic Hospital',
                                           'University ':'University',
                                           'college':'College',
                                           'School Boards':'School Board',
                                           'Municipal':'Municipal Service Board',
                                           })

# %%
df['Organization'].value_counts()
# Out:
# Organization
# City of Toronto                                           96020
# Toronto District School Board                              2839
# Peel District School Board                                 1350
# City of Ottawa                                             1171
# York Region District School Board                          1129
#                                                           ...
# Sudbury St. Joseph's Continuing Care Centre of Sudbury        2
# Township of Evanturel                                         2
# Elliot Lake St. Joseph's General Hospital                     1
# Alliston Stevenson Memorial                                   1
# Toronto Providence Healthcare                                 1
# Name: count, Length: 716, dtype: int64

# %%
df['Organization'].value_counts()
# Out:
# Organization
# City of Toronto                                           96020
# Toronto District School Board                              2839
# Peel District School Board                                 1350
# City of Ottawa                                             1171
# York Region District School Board                          1129
#                                                           ...
# Sudbury St. Joseph's Continuing Care Centre of Sudbury        2
# Township of Evanturel                                         2
# Elliot Lake St. Joseph's General Hospital                     1
# Alliston Stevenson Memorial                                   1
# Toronto Providence Healthcare                                 1
# Name: count, Length: 716, dtype: int64

# %%
df['Organization'].value_counts()
# Out:
# Organization
# City of Toronto                                           96020
# Toronto District School Board                              2839
# Peel District School Board                                 1350
# City of Ottawa                                             1171
# York Region District School Board                          1129
#                                                           ...
# Sudbury St. Joseph's Continuing Care Centre of Sudbury        2
# Township of Evanturel                                         2
# Elliot Lake St. Joseph's General Hospital                     1
# Alliston Stevenson Memorial                                   1
# Toronto Providence Healthcare                                 1
# Name: count, Length: 716, dtype: int64

# %%
df['Operation Type'].value_counts()
# Out:
# Operation Type
# School                                                                                 112282
# Other                                                                                    7397
# Storage facilities where equipment or vehicles are maintained, repaired or stored        6288
# Administrative offices and related facilities, including municipal council chambers      5729
# Fire stations and associated offices and facilities                                      5560
# Community centres                                                                        5048
# Facilities related to the pumping of sewage                                              3396
# Cultural facilities                                                                      2685
# Public libraries                                                                         2645
# Facilities related to the pumping of water                                               2543
# Facilities related to the treatment of water                                             2358
# Administrative offices and related facilities                                            2232
# Indoor recreational facilities                                                           1771
# Indoor ice rinks                                                                         1746
# Facilities related to the treatment of sewage                                            1684
# Ambulance stations and associated offices and facilities                                 1419
# Facilities used for hospital purposes                                                    1298
# Classrooms and related facilities                                                        1241
# Police stations and associated offices and facilities                                     965
# Street lighting                                                                           904
# Parking garages                                                                           874
# Laboratories                                                                              646
# Indoor swimming pools                                                                     473
# Social housing                                                                            466
# Indoor sports arenas                                                                      462
# Student residences                                                                        399
# Library                                                                                   235
# Long-term care                                                                            224
# Gyms and indoor courts for playing tennis, basketball or other sports                     223
# Performing arts facilities                                                                204
# Student recreational facilities and athletic facilities                                   203
# Art galleries                                                                             138
# Auditoriums                                                                                81
# Parking garage                                                                             30
# Installations utilisées pour des besoins hospitaliers                                       1
# Name: count, dtype: int64

# %%
df['Unit of Measure'].value_counts()
# Out:
# Unit of Measure
# Square feet      156766
# Square meters     17083
# Mètres carrés         1
# Name: count, dtype: int64

# %%
df['Unit of Measure'] = df['Unit of Measure'].replace({'Sq Ft':'Square Feet',
                                                       'x':'Square Feet',
                                                       'Square feet':'Square Feet',
                                                       'square feet':'Square Feet',
                                                       'Square meters':'Square Meters',
                                                       'square meters':'Square Meters',
                                                       'mètres carrés':'Mètres carrés',
                                                       'Mètres carrés':'Metres Carres',
                                                       'pieds carrés':'Pieds carrés',
                                                       'Pieds carrés':'Pieds Carres'
                                           })

# %%
df['Electricity_Unit'].value_counts()
# Out:
# Electricity_Unit
# kWh    173848
# KWh         2
# Name: count, dtype: int64

# %%
df['Electricity_Unit'] = df['Electricity_Unit'].replace({'kWh':'KWh',
                                                         'kwh':'KWh',
                                                         'x':'KWh'
                                                       
                                           })

# %%
df['NaturalGas_Unit'].value_counts()
# Out:
# NaturalGas_Unit
# Cubic Meter    173484
# ekWh              203
# Giga Joule        153
# Cubic meter         9
# mètre cube          1
# Name: count, dtype: int64

# %%
df['NaturalGas_Unit'] = df['NaturalGas_Unit'].replace({'Cubic meter':'Cubic Meter',
                                                       'cubic meter':'Cubic Meter',
                                                       'mètre cube':'Cubic Meter',
                                                       'x':'ekWh',
                                                       'Litre':'ekWh',
                                                       'ekwh':'ekWh'
                                           })

# %%
df['FuelOil12_Unit'].value_counts()
# Out:
# FuelOil12_Unit
# Litre    173850
# Name: count, dtype: int64

# %%
df['FuelOil12_Unit'] = df['FuelOil12_Unit'].replace({'Litres':'Litre',
                                                         'litre':'Litre',})

# %%
df['FuelOil46_Unit'].value_counts()
# Out:
# FuelOil46_Unit
# Litre    173850
# Name: count, dtype: int64

# %%
df['Propane_Unit'].value_counts()
# Out:
# Propane_Unit
# Litre        173846
# 125544.62         1
# 36052.69          1
# 123351.09         1
# 18181.02          1
# Name: count, dtype: int64

# %%
df['Propane_Unit'] = df['Propane_Unit'].replace({
    125544.62: 'Litre',
    36052.69: 'Litre',
    123351.09: 'Litre',
    18181.02: 'Litre'})

# %%
df['Coal_Unit'].value_counts()
# Out:
# Coal_Unit
# Metric Tonne    173850
# Name: count, dtype: int64

# %%
df['Coal_Unit'] = df['Coal_Unit'].replace({'Metric tonne':'Metric Tonne',
                                                         'Tonne métrique':'Metric Tonne',})

# %%
df['Wood_Unit'].value_counts()
# Out:
# Wood_Unit
# Metric Tonne    173850
# Name: count, dtype: int64

# %%
df['Wood_Unit'] = df['Wood_Unit'].replace({'Metric tonne':'Metric Tonne',
                                                         'Tonne métrique':'Metric Tonne',})

# %%
df['DistrictHeating_Unit'].value_counts()
# Out:
# DistrictHeating_Unit
# Giga Joule      173785
# Metric Tonne        64
# KL Hot Water         1
# Name: count, dtype: int64

# %%
df['DistrictHeating_Unit'] = df['DistrictHeating_Unit'].replace({'Giga Joule - steam or hot water':'Giga Joule',
                                                       'Gigajoule - vapeur ou eau chaude':'Giga Joule',
                                                       'metric tonne - steam':'Metric Tonne',
                                                       'kilolitre - hot water':'kilolitre',
                                                       'KL Hot Water':'kilolitre', })

# %%
df['DistrictCooling_Unit'].value_counts()
# Out:
# DistrictCooling_Unit
# Giga Joule          173808
# KL Chilled Water        42
# Name: count, dtype: int64

# %%
df['DistrictCooling_Unit'] = df['DistrictCooling_Unit'].replace({'Giga Joule - chilled water':'Giga Joule',
                                                       'Gigajoule':'Giga Joule',
                                                       'kilolitre - chilled water':'kilolitre',
                                                       'KL Chilled Water':'kilolitre', })

# %%
df['Swimming Pool'].value_counts()
# Out:
# Swimming Pool
# No     173405
# Yes       445
# Name: count, dtype: int64

# %%
df['Swimming Pool'] = df['Swimming Pool'].replace({1.0:'Yes',
                                                       0.0:'non',
                                                       'S.O.':'Yes',
                                                        })

# %%
df['Swimming Pool'].value_counts()
# Out:
# Swimming Pool
# No     173405
# Yes       445
# Name: count, dtype: int64

# %%
df.to_csv('C:\\Users\\M SWETHA\\Downloads\\final.csv')

# %%
df=pd.read_csv('C:\\Users\\M SWETHA\\Downloads\\final.csv')
df
# Out:
#         Unnamed: 0  \
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...
# 173845      173845
# 173846      173846
# 173847      173847
# 173848      173848
# 173849      173849
#
#        The GJ/m2 column has been updated to address conversion irregularities.  \
# 0                                               Municipal
# 1                                             Sector Name
# 2                                               Municipal
# 3                                               Municipal
# 4                                               Municipal
# ...                                                   ...
# 173845             Post-secondary Educational Institution
# 173846             Post-secondary Educational Institution
# 173847             Post-secondary Educational Institution
# 173848             Post-secondary Educational Institution
# 173849             Post-secondary Educational Institution
#
#             Unnamed: 1         Unnamed: 2  \
# 0         Municipality    City of Toronto
# 1       SubSector Name  Organization Name
# 2         Municipality   Town of Goderich
# 3         Municipality   Town of Goderich
# 4         Municipality   Town of Goderich
# ...                ...                ...
# 173845     University     York University
# 173846     University     York University
# 173847     University     York University
# 173848     University     York University
# 173849     University     York University
#
#                                             Unnamed: 3  \
# 0                                     Municipal Office
# 1                                       Operation Name
# 2                                     Municipal Office
# 3                                     Goderich Library
# 4                                Water Treatment Plant
# ...                                                ...
# 173845  William Small Centre - PS2 Face Building (398)
# 173846                           Winters College (368)
# 173847                                 York Hall (304)
# 173848                          York Lanes (383) (450)
# 173849                 York University Bookstore (203)
#
#                                                Unnamed: 4  \
# 0                                                  School
# 1                                          Operation Type
# 2       Administrative offices and related facilities,...
# 3                                        Public libraries
# 4            Facilities related to the treatment of water
# ...                                                   ...
# 173845      Administrative offices and related facilities
# 173846      Administrative offices and related facilities
# 173847      Administrative offices and related facilities
# 173848      Administrative offices and related facilities
# 173849      Administrative offices and related facilities
#
#                    Unnamed: 5 Unnamed: 6   Unnamed: 7        Unnamed: 8  \
# 0       Intentionally Omitted    Toronto      M3J 1P3                 0
# 1                     Address       City  Postal Code  Total Floor Area
# 2              57 West Street   Goderich      N7A 2K5             21510
# 3          52 Montreal Street   Goderich      N7A 2K5              1100
# 4                 100 Cove Rd   Goderich      N7A 2K5               733
# ...                       ...        ...          ...               ...
# 173845      4700 Keele Street    Toronto       M3J1P3           4812.49
# 173846      4700 Keele Street    Toronto       M3J1P3           6897.26
# 173847    2275 Bayview Avenue    Toronto       M4N3M6          19992.81
# 173848      4700 Keele Street    Toronto       M3J1P3          10533.75
# 173849      4700 Keele Street    Toronto       M3J1P3           2482.49
#
#            Unnamed: 9  Unnamed: 10             Unnamed: 11  Unnamed: 12  \
# 0         Square feet          168                       0            0
# 1               Unit1  Annual Flow  Average Hours Per Week  Electricity
# 2         Square feet          168                      40       248444
# 3       Square meters          168                      62       100147
# 4       Square meters     1405.631                     168       994783
# ...               ...          ...                     ...          ...
# 173845  Square meters         61.0                     0.0    1898435.0
# 173846  Square meters         85.0                     0.0    1585386.0
# 173847  Square meters        112.0                     0.0    1829015.0
# 173848  Square meters        133.0                     0.0      90990.0
# 173849  Square meters         50.0                     0.0     548509.0
#
#        Unnamed: 13  Unnamed: 14  Unnamed: 15     Unnamed: 16  Unnamed: 17  \
# 0              kWh            0          kWh               0  Cubic Meter
# 1            Unit2  Natural Gas        Unit3  Fuel Oil 1 & 2        Unit4
# 2              kWh        202.6  Cubic meter               0  Cubic Meter
# 3              kWh      18694.7  Cubic meter               0  Cubic Meter
# 4              kWh            0          kWh               0  Cubic Meter
# ...            ...          ...          ...             ...          ...
# 173845         kWh          0.0  Cubic Meter             0.0        Litre
# 173846         kWh          0.0  Cubic Meter             0.0        Litre
# 173847         kWh          0.0  Cubic Meter             0.0        Litre
# 173848         kWh     244044.0  Cubic Meter             0.0        Litre
# 173849         kWh          0.0  Cubic Meter             0.0        Litre
#
#            Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0                    0       Litre           0       Litre           0
# 1       Fuel Oil 4 & 6       Unit5     Propane       Unit6        Coal
# 2                    0       Litre           0       Litre           0
# 3                    0       Litre           0       Litre           0
# 4                    0       Litre           0       Litre           0
# ...                ...         ...         ...         ...         ...
# 173845             0.0       Litre         0.0       Litre           0
# 173846             0.0       Litre         0.0       Litre           0
# 173847             0.0       Litre         0.0       Litre           0
# 173848             0.0       Litre         0.0       Litre           0
# 173849             0.0       Litre         0.0       Litre           0
#
#          Unnamed: 23 Unnamed: 24   Unnamed: 25    Unnamed: 26 Unnamed: 27  \
# 0       Metric Tonne           0  Metric Tonne              0  Giga Joule
# 1              Unit7        Wood         Unit8  District Heat       Unit9
# 2       Metric Tonne           0  Metric Tonne              0  Giga Joule
# 3       Metric Tonne           0  Metric Tonne              0  Giga Joule
# 4       Metric Tonne           0  Metric Tonne              0  Giga Joule
# ...              ...         ...           ...            ...         ...
# 173845  Metric Tonne           0  Metric Tonne       4580.683  Giga Joule
# 173846  Metric Tonne           0  Metric Tonne       17026.69  Giga Joule
# 173847  Metric Tonne           0  Metric Tonne       14146.56  Giga Joule
# 173848  Metric Tonne           0  Metric Tonne            0.0  Giga Joule
# 173849  Metric Tonne           0  Metric Tonne            0.0  Giga Joule
#
#        Unnamed: 28       Unnamed: 29    Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 0            False                 0              0           0       False
# 1       Renewable1  Emission Factor1  District Cool      Unit10  Renewable2
# 2            False                 0              0           0       False
# 3            False                 0              0           0       False
# 4            False                 0              0           0       False
# ...            ...               ...            ...         ...         ...
# 173845       False               0.0       1910.829  Giga Joule       False
# 173846       False               0.0       2374.588  Giga Joule       False
# 173847       False               0.0            0.0  Giga Joule       False
# 173848       False               0.0       4050.645  Giga Joule       False
# 173849       False               0.0       1377.224  Giga Joule       False
#
#              Unnamed: 33    Unnamed: 34          Unnamed: 35  \
# 0                      0          False                    0
# 1       Emission Factor2  Swimming Pool  Number of Portables
# 2                      0          False                    0
# 3                      0          False                    0
# 4                      0          False                    0
# ...                  ...            ...                  ...
# 173845                 0            0.0                False
# 173846                 0            0.0                False
# 173847                 0            0.0                False
# 173848                 0            0.0                False
# 173849                 0            0.0                False
#
#                Unnamed: 36                 Unnamed: 37  \
# 0                        0                           0
# 1        GHG Emissions(Kg)  Energy Intensity ekWh_sqft
# 2       24740.490790199998           11.65026441748954
# 3            45163.1164569           25.23756669857642
# 4              97528.52532          126.07825843680682
# ...                    ...                         ...
# 173845       469399.795928                   64.316827
# 173846      1181110.522967                   87.752824
# 173847      1014525.321786                   26.759251
# 173848       502880.945826                   26.684434
# 173849        63812.513172                   24.865427
#
#                              Unnamed: 38             Unnamed: 39  \
# 0                                      0                       0
# 1       Energy Intensity ekWh_mega_litre  Energy Intensity GJ_m2
# 2                                      0     0.45144884373308924
# 3                                      0      0.9779894745454546
# 4                      707.7127638761524       4.885700954979536
# ...                                  ...                     ...
# 173845                               0.0                2.492283
# 173846                               0.0                 3.40043
# 173847                               0.0                1.036923
# 173848                               0.0                1.034024
# 173849                               0.0                0.963538
#
#                            Unnamed: 40     Sector     SubSector  \
# 0                                    0  Municipal  Municipality
# 1       Energy Intensity GJ_mega_litre  Municipal  Municipality
# 2                                    0  Municipal  Municipality
# 3                                    0  Municipal  Municipality
# 4                    2.547765929572021  Municipal  Municipality
# ...                                ...        ...           ...
# 173845                             0.0  Municipal  Municipality
# 173846                             0.0  Municipal  Municipality
# 173847                             0.0  Municipal  Municipality
# 173848                             0.0  Municipal  Municipality
# 173849                             0.0  Municipal  Municipality
#
#            Organization         Operation Operation Type  \
# 0       City of Toronto  Municipal Office         School
# 1       City of Toronto  Municipal Office         School
# 2       City of Toronto  Municipal Office         School
# 3       City of Toronto  Municipal Office         School
# 4       City of Toronto  Municipal Office         School
# ...                 ...               ...            ...
# 173845  City of Toronto  Municipal Office         School
# 173846  City of Toronto  Municipal Office         School
# 173847  City of Toronto  Municipal Office         School
# 173848  City of Toronto  Municipal Office         School
# 173849  City of Toronto  Municipal Office         School
#
#                               Address     City Postal Code  \
# 0       public works related facility  Toronto     L6P 1K7
# 1       public works related facility  Toronto     L6P 1K7
# 2       public works related facility  Toronto     L6P 1K7
# 3       public works related facility  Toronto     L6P 1K7
# 4       public works related facility  Toronto     L6P 1K7
# ...                               ...      ...         ...
# 173845  public works related facility  Toronto     L6P 1K7
# 173846  public works related facility  Toronto     L6P 1K7
# 173847  public works related facility  Toronto     L6P 1K7
# 173848  public works related facility  Toronto     L6P 1K7
# 173849  public works related facility  Toronto     L6P 1K7
#
#         Total Indoor Space_x Unit of Measure  Weekly Average Hours  \
# 0               62193.294512     Square Feet             86.723544
# 1               62193.294512     Square Feet             86.723544
# 2               62193.294512     Square Feet             86.723544
# 3               62193.294512     Square Feet             86.723544
# 4               62193.294512     Square Feet             86.723544
# ...                      ...             ...                   ...
# 173845          62193.294512     Square Feet             86.723544
# 173846          62193.294512     Square Feet             86.723544
# 173847          62193.294512     Square Feet             86.723544
# 173848          62193.294512     Square Feet             86.723544
# 173849          62193.294512     Square Feet             86.723544
#
#         Annual Flow (M)  Number of Portables Swimming Pool  \
# 0          26559.940671             0.454669            No
# 1          26559.940671             0.454669            No
# 2          26559.940671             0.454669            No
# 3          26559.940671             0.454669            No
# 4          26559.940671             0.454669            No
# ...                 ...                  ...           ...
# 173845     26559.940671             0.454669            No
# 173846     26559.940671             0.454669            No
# 173847     26559.940671             0.454669            No
# 173848     26559.940671             0.454669            No
# 173849     26559.940671             0.454669            No
#
#         Electricity_Quantity Electricity_Unit  NaturalGas_Quantity  \
# 0              583286.618229              KWh         65775.708054
# 1              583286.618229              KWh         65775.708054
# 2              583286.618229              KWh         65775.708054
# 3              583286.618229              KWh         65775.708054
# 4              583286.618229              KWh         65775.708054
# ...                      ...              ...                  ...
# 173845         583286.618229              KWh         65775.708054
# 173846         583286.618229              KWh         65775.708054
# 173847         583286.618229              KWh         65775.708054
# 173848         583286.618229              KWh         65775.708054
# 173849         583286.618229              KWh         65775.708054
#
#        NaturalGas_Unit  FuelOil12_Quantity FuelOil12_Unit  FuelOil46_Quantity  \
# 0          Cubic Meter          459.887452          Litre           37.766504
# 1          Cubic Meter          459.887452          Litre           37.766504
# 2          Cubic Meter          459.887452          Litre           37.766504
# 3          Cubic Meter          459.887452          Litre           37.766504
# 4          Cubic Meter          459.887452          Litre           37.766504
# ...                ...                 ...            ...                 ...
# 173845     Cubic Meter          459.887452          Litre           37.766504
# 173846     Cubic Meter          459.887452          Litre           37.766504
# 173847     Cubic Meter          459.887452          Litre           37.766504
# 173848     Cubic Meter          459.887452          Litre           37.766504
# 173849     Cubic Meter          459.887452          Litre           37.766504
#
#        FuelOil46_Unit  Propane_Quantity Propane_Unit  Coal_Quantity  \
# 0               Litre        875.884213        Litre            0.0
# 1               Litre        875.884213        Litre            0.0
# 2               Litre        875.884213        Litre            0.0
# 3               Litre        875.884213        Litre            0.0
# 4               Litre        875.884213        Litre            0.0
# ...               ...               ...          ...            ...
# 173845          Litre        875.884213        Litre            0.0
# 173846          Litre        875.884213        Litre            0.0
# 173847          Litre        875.884213        Litre            0.0
# 173848          Litre        875.884213        Litre            0.0
# 173849          Litre        875.884213        Litre            0.0
#
#            Coal_Unit  Wood_Quantity     Wood_Unit  DistrictHeating_Quantity  \
# 0       Metric Tonne       0.012873  Metric Tonne               2123.751138
# 1       Metric Tonne       0.012873  Metric Tonne               2123.751138
# 2       Metric Tonne       0.012873  Metric Tonne               2123.751138
# 3       Metric Tonne       0.012873  Metric Tonne               2123.751138
# 4       Metric Tonne       0.012873  Metric Tonne               2123.751138
# ...              ...            ...           ...                       ...
# 173845  Metric Tonne       0.012873  Metric Tonne               2123.751138
# 173846  Metric Tonne       0.012873  Metric Tonne               2123.751138
# 173847  Metric Tonne       0.012873  Metric Tonne               2123.751138
# 173848  Metric Tonne       0.012873  Metric Tonne               2123.751138
# 173849  Metric Tonne       0.012873  Metric Tonne               2123.751138
#
#        DistrictHeating_Unit  DistrictHeating_IsRenewable  \
# 0                Giga Joule                          NaN
# 1                Giga Joule                          NaN
# 2                Giga Joule                          NaN
# 3                Giga Joule                          NaN
# 4                Giga Joule                          NaN
# ...                     ...                          ...
# 173845           Giga Joule                          NaN
# 173846           Giga Joule                          NaN
# 173847           Giga Joule                          NaN
# 173848           Giga Joule                          NaN
# 173849           Giga Joule                          NaN
#
#         DistrictHeating_RenewableEmissionFactor  DistrictCooling_Quantity  \
# 0                                      0.035018                 38.749584
# 1                                      0.035018                 38.749584
# 2                                      0.035018                 38.749584
# 3                                      0.035018                 38.749584
# 4                                      0.035018                 38.749584
# ...                                         ...                       ...
# 173845                                 0.035018                 38.749584
# 173846                                 0.035018                 38.749584
# 173847                                 0.035018                 38.749584
# 173848                                 0.035018                 38.749584
# 173849                                 0.035018                 38.749584
#
#        DistrictCooling_Unit  DistrictCooling_IsRenewable  \
# 0                Giga Joule                          NaN
# 1                Giga Joule                          NaN
# 2                Giga Joule                          NaN
# 3                Giga Joule                          NaN
# 4                Giga Joule                          NaN
# ...                     ...                          ...
# 173845           Giga Joule                          NaN
# 173846           Giga Joule                          NaN
# 173847           Giga Joule                          NaN
# 173848           Giga Joule                          NaN
# 173849           Giga Joule                          NaN
#
#         DistrictCooling_RenewableEmissionFactor  GHG Emissions KG  \
# 0                                      0.001417     270524.755372
# 1                                      0.001417     270524.755372
# 2                                      0.001417     270524.755372
# 3                                      0.001417     270524.755372
# 4                                      0.001417     270524.755372
# ...                                         ...               ...
# 173845                                 0.001417     270524.755372
# 173846                                 0.001417     270524.755372
# 173847                                 0.001417     270524.755372
# 173848                                 0.001417     270524.755372
# 173849                                 0.001417     270524.755372
#
#         Energy Intensity ekWh_sqft  Energy Intensity ekWh_mega_litre  \
# 0                     23480.507098                      3.511400e+12
# 1                     23480.507098                      3.511400e+12
# 2                     23480.507098                      3.511400e+12
# 3                     23480.507098                      3.511400e+12
# 4                     23480.507098                      3.511400e+12
# ...                            ...                               ...
# 173845                23480.507098                      3.511400e+12
# 173846                23480.507098                      3.511400e+12
# 173847                23480.507098                      3.511400e+12
# 173848                23480.507098                      3.511400e+12
# 173849                23480.507098                      3.511400e+12
#
#         Energy Intensity GJ_m2  Energy Intensity GJ_mega_litre
# 0                   915.817854                    1.272888e+10
# 1                   915.817854                    1.272888e+10
# 2                   915.817854                    1.272888e+10
# 3                   915.817854                    1.272888e+10
# 4                   915.817854                    1.272888e+10
# ...                        ...                             ...
# 173845              915.817854                    1.272888e+10
# 173846              915.817854                    1.272888e+10
# 173847              915.817854                    1.272888e+10
# 173848              915.817854                    1.272888e+10
# 173849              915.817854                    1.272888e+10
#
# [173850 rows x 83 columns]
